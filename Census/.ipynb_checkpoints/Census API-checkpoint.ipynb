# %%
import censusdata
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy import stats

# %%
# Specify path to read file
path = os.path.join("Resources", "USCS_OverviewMap.csv")

# Read in pandas
df = pd.read_csv(path)

# %%
states = censusdata.geographies(censusdata.censusgeo([('state', '*')]), 'acs5', 2017)

# print(states['California'])

# %%
# unemploy = censusdata.search('acs5', 2017, 'label', 'living alone')
# unemploy

# %%
# Download ACS 2011-2015 5-year estimates for Oakland city, California on population size, median age, and median household income.
data = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '*')]), ['B01001_001E', 'B01002_001E', 'B19013_001E','B12006_006E','B12006_011E','B17005_006E', "B17005_011E", "C27016_041E", "B19215_005E", "B19215_008E", "B09019_027E", "B09019_030E"])

data_table = data.rename(columns={"B01001_001E": "population size", "B01002_001E": "median age",
                                  "B19013_001E" : "median household income", "B12006_006E" : "NeverMarried Unemployed Male", 
                                  "B12006_011E" : "NeverMarried Unemployed Female", "B17005_006E" : "Unemployed Male below line", 
                                  "B17005_011E" : "Unemployed Female below line", "C27016_041E" : "4.00 of poverty threshold 65 years and over No health insurance coverage",
                                  "B19215_005E" : "MEDIAN HOUSEHOLD INCOME Living Alone 65 and over", "B19215_008E" : "MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over",
                                  "B09019_027E" : "Male Living alone", "B09019_030E" : "Female Living alone"})
# data_table.head()

# %%
data_table.index = data_table.index.astype(str)
data_table["Area"] = data_table.index.str.split(':').str[0]

# data_table.head()

# %%
deathrates_census = pd.merge(df, data_table, on="Area")

# %%
deathrates_census
# Out:
#                     Area           CancerType  Year              Sex  \
# 0                 Nevada  All Types of Cancer  2017  Male and Female
# 1                  Idaho  All Types of Cancer  2017  Male and Female
# 2                Wyoming  All Types of Cancer  2017  Male and Female
# 3               Colorado  All Types of Cancer  2017  Male and Female
# 4                Georgia  All Types of Cancer  2017  Male and Female
# 5                Montana  All Types of Cancer  2017  Male and Female
# 6                  Texas  All Types of Cancer  2017  Male and Female
# 7             New Mexico  All Types of Cancer  2017  Male and Female
# 8                   Utah  All Types of Cancer  2017  Male and Female
# 9             California  All Types of Cancer  2017  Male and Female
# 10                Alaska  All Types of Cancer  2017  Male and Female
# 11                Oregon  All Types of Cancer  2017  Male and Female
# 12              Virginia  All Types of Cancer  2017  Male and Female
# 13           Mississippi  All Types of Cancer  2017  Male and Female
# 14         West Virginia  All Types of Cancer  2017  Male and Female
# 15          Rhode Island  All Types of Cancer  2017  Male and Female
# 16             Minnesota  All Types of Cancer  2017  Male and Female
# 17              Maryland  All Types of Cancer  2017  Male and Female
# 18            Washington  All Types of Cancer  2017  Male and Female
# 19                Hawaii  All Types of Cancer  2017  Male and Female
# 20  District of Columbia  All Types of Cancer  2017  Male and Female
# 21              Missouri  All Types of Cancer  2017  Male and Female
# 22          North Dakota  All Types of Cancer  2017  Male and Female
# 23             Tennessee  All Types of Cancer  2017  Male and Female
# 24              Nebraska  All Types of Cancer  2017  Male and Female
# 25              Oklahoma  All Types of Cancer  2017  Male and Female
# 26              Arkansas  All Types of Cancer  2017  Male and Female
# 27                  Iowa  All Types of Cancer  2017  Male and Female
# 28               Florida  All Types of Cancer  2017  Male and Female
# 29             Wisconsin  All Types of Cancer  2017  Male and Female
# 30                Kansas  All Types of Cancer  2017  Male and Female
# 31        North Carolina  All Types of Cancer  2017  Male and Female
# 32          South Dakota  All Types of Cancer  2017  Male and Female
# 33          Pennsylvania  All Types of Cancer  2017  Male and Female
# 34              Kentucky  All Types of Cancer  2017  Male and Female
# 35               Alabama  All Types of Cancer  2017  Male and Female
# 36                 Maine  All Types of Cancer  2017  Male and Female
# 37        South Carolina  All Types of Cancer  2017  Male and Female
# 38             Louisiana  All Types of Cancer  2017  Male and Female
# 39               Vermont  All Types of Cancer  2017  Male and Female
# 40               Arizona  All Types of Cancer  2017  Male and Female
# 41                  Ohio  All Types of Cancer  2017  Male and Female
# 42            New Jersey  All Types of Cancer  2017  Male and Female
# 43              Delaware  All Types of Cancer  2017  Male and Female
# 44         New Hampshire  All Types of Cancer  2017  Male and Female
# 45              New York  All Types of Cancer  2017  Male and Female
# 46              Illinois  All Types of Cancer  2017  Male and Female
# 47               Indiana  All Types of Cancer  2017  Male and Female
# 48         Massachusetts  All Types of Cancer  2017  Male and Female
# 49              Michigan  All Types of Cancer  2017  Male and Female
# 50           Connecticut  All Types of Cancer  2017  Male and Female
#
#          Race  AgeAdjustedRate  DeathCount  Population  population size  \
# 0   All Races            156.3        5283     2972405          2887725
# 1   All Races            153.2        3020     1718904          1657375
# 2   All Races            136.0         948      578934           583200
# 3   All Races            131.1        7829     5615902          5436519
# 4   All Races            155.4       17135    10413055         10201635
# 5   All Races            152.1        2145     1053090          1029862
# 6   All Races            147.3       40668    28322717         27419612
# 7   All Races            138.2        3620     2093395          2084828
# 8   All Races            121.0        3160     3103118          2993941
# 9   All Races            137.2       59515    39399349         38982847
# 10  All Races            139.8         926      739786           738565
# 11  All Races            154.1        8083     4146592          4025127
# 12  All Races            152.5       15064     8465207          8365952
# 13  All Races            182.8        6526     2989663          2986220
# 14  All Races            178.6        4654     1817048          1836843
# 15  All Races            154.0        2154     1056486          1056138
# 16  All Races            147.1        9896     5568155          5490726
# 17  All Races            151.8       10796     6024891          5996079
# 18  All Races            148.4       12664     7425432          7169967
# 19  All Races            128.5        2456     1424203          1421658
# 20  All Races            152.5        1031      695691           672391
# 21  All Races            167.1       12971     6108612          6075300
# 22  All Races            142.2        1280      755176           745475
# 23  All Races            173.5       14302     6708794          6597381
# 24  All Races            152.9        3502     1917575          1893921
# 25  All Races            176.7        8203     3932640          3896251
# 26  All Races            173.3        6516     3002997          2977944
# 27  All Races            157.8        6449     3143637          3118102
# 28  All Races            145.3       45129    20976812         20278447
# 29  All Races            153.3       11318     5792051          5763217
# 30  All Races            157.1        5493     2910689          2903820
# 31  All Races            157.2       19474    10270800         10052564
# 32  All Races            157.4        1715      873286           855444
# 33  All Races            160.6       28385    12790447         12790505
# 34  All Races            186.0       10145     4453874          4424376
# 35  All Races            169.5       10410     4875120          4850771
# 36  All Races            169.7        3391     1335063          1330158
# 37  All Races            162.6       10356     5021219          4893444
# 38  All Races            174.7        9512     4670818          4663461
# 39  All Races            164.4        1434      624525           624636
# 40  All Races            134.9       12008     7048876          6809946
# 41  All Races            171.1       25643    11664129         11609756
# 42  All Races            145.7       16264     8888543          8960161
# 43  All Races            160.9        2085      957078           943732
# 44  All Races            153.2        2760     1349767          1331848
# 45  All Races            142.0       34956    19590719         19798228
# 46  All Races            158.3       24150    12786196         12854526
# 47  All Races            170.4       13462     6660082          6614418
# 48  All Races            149.4       12934     6863246          6789319
# 49  All Races            161.2       20671     9976447          9925568
# 50  All Races            139.8        6608     3573880          3594478
#
#     median age  median household income  NeverMarried Unemployed Male  \
# 0         37.7                    55434                         34511
# 1         35.9                    50985                         13043
# 2         37.0                    60938                          4656
# 3         36.5                    65458                         48543
# 4         36.4                    52977                        113761
# 5         39.8                    50801                          7871
# 6         34.3                    57051                        236953
# 7         37.3                    46718                         25416
# 8         30.5                    65325                         20902
# 9         36.1                    67169                        479114
# 10        33.9                    76114                         10535
# 11        39.2                    56119                         43276
# 12        38.0                    68766                         75992
# 13        36.9                    42009                         37752
# 14        42.2                    44061                         18965
# 15        39.9                    61043                         12027
# 16        37.9                    65699                         45690
# 17        38.5                    78916                         65309
# 18        37.6                    66174                         71307
# 19        38.8                    74923                         11153
# 20        33.9                    77649                         11067
# 21        38.4                    51542                         55315
# 22        35.1                    61285                          4216
# 23        38.6                    48708                         62875
# 24        36.3                    56675                         12656
# 25        36.3                    49767                         32038
# 26        37.9                    43813                         25507
# 27        38.1                    56570                         23006
# 28        41.8                    50883                        210344
# 29        39.2                    56759                         48839
# 30        36.3                    55477                         22616
# 31        38.4                    50320                        108201
# 32        36.8                    54126                          6096
# 33        40.7                    56951                        145170
# 34        38.6                    46535                         43158
# 35        38.7                    46472                         52588
# 36        44.3                    53024                         11967
# 37        39.0                    48781                         54886
# 38        36.4                    46710                         56484
# 39        42.8                    57808                          4879
# 40        37.2                    53510                         72421
# 41        39.3                    52407                        127220
# 42        39.6                    76475                        100719
# 43        39.8                    63036                         10317
# 44        42.7                    71305                         10826
# 45        38.4                    62765                        235709
# 46        37.7                    61229                        162438
# 47        37.5                    52182                         64770
# 48        39.4                    74167                         75007
# 49        39.6                    52668                        122940
# 50        40.8                    73781                         46584
#
#     NeverMarried Unemployed Female  Unemployed Male below line  \
# 0                            23373                       19627
# 1                             8996                        7066
# 2                             2443                        2094
# 3                            30309                       21924
# 4                            96225                       57643
# 5                             4496                        4586
# 6                           172816                      109949
# 7                            16614                       15033
# 8                            13961                        8770
# 9                           337696                      222854
# 10                            5475                        4418
# 11                           28696                       24537
# 12                           55828                       30703
# 13                           33752                       22463
# 14                           10544                       12053
# 15                            9883                        5632
# 16                           27671                       19195
# 17                           50928                       22503
# 18                           45120                       34984
# 19                            6863                        4267
# 20                           10626                        5309
# 21                           40234                       29289
# 22                            2478                        2099
# 23                           50292                       37735
# 24                            9500                        6075
# 25                           22159                       18549
# 26                           17932                       15981
# 27                           14789                       10636
# 28                          153664                      116958
# 29                           33143                       25184
# 30                           15902                       10871
# 31                           85413                       59486
# 32                            4403                        3559
# 33                          101702                       63989
# 34                           30049                       28228
# 35                           41989                       28358
# 36                            7532                        6138
# 37                           44436                       28529
# 38                           41259                       27242
# 39                            3798                        2040
# 40                           51529                       40770
# 41                           94246                       69735
# 42                           75126                       35390
# 43                            6914                        3745
# 44                            6780                        4118
# 45                          170807                      103399
# 46                          123572                       76943
# 47                           47620                       33203
# 48                           52527                       27632
# 49                           92610                       68102
# 50                           32914                       16809
#
#     Unemployed Female below line  \
# 0                          17581
# 1                           5906
# 2                           1833
# 3                          19648
# 4                          72843
# 5                           3555
# 6                         124794
# 7                          14125
# 8                           8605
# 9                         218801
# 10                          3161
# 11                         23727
# 12                         36068
# 13                         27887
# 14                         10048
# 15                          6546
# 16                         16797
# 17                         26373
# 18                         29406
# 19                          3949
# 20                          7286
# 21                         32570
# 22                          1400
# 23                         41814
# 24                          6283
# 25                         18209
# 26                         16880
# 27                         11287
# 28                        124970
# 29                         22857
# 30                         11296
# 31                         69382
# 32                          3193
# 33                         64401
# 34                         27079
# 35                         34852
# 36                          5288
# 37                         33509
# 38                         33119
# 39                          2416
# 40                         38824
# 41                         70044
# 42                         41289
# 43                          4109
# 44                          3621
# 45                        105175
# 46                         81812
# 47                         37770
# 48                         29162
# 49                         65821
# 50                         19398
#
#     4.00 of poverty threshold 65 years and over No health insurance coverage  \
# 0                                                2377
# 1                                                 230
# 2                                                  74
# 3                                                1314
# 4                                                3374
# 5                                                 126
# 6                                               16359
# 7                                                1000
# 8                                                 868
# 9                                               17678
# 10                                                494
# 11                                                670
# 12                                               3328
# 13                                                342
# 14                                                 27
# 15                                                148
# 16                                                598
# 17                                               3071
# 18                                               2142
# 19                                                591
# 20                                                154
# 21                                                847
# 22                                                 58
# 23                                               1305
# 24                                                217
# 25                                                801
# 26                                                594
# 27                                                306
# 28                                              13555
# 29                                                616
# 30                                                469
# 31                                               1809
# 32                                                 82
# 33                                               2289
# 34                                                593
# 35                                                759
# 36                                                106
# 37                                                759
# 38                                               1037
# 39                                                 22
# 40                                               2140
# 41                                               2542
# 42                                               5222
# 43                                                422
# 44                                                156
# 45                                               7232
# 46                                               4889
# 47                                               1301
# 48                                               1080
# 49                                               1354
# 50                                                775
#
#     MEDIAN HOUSEHOLD INCOME Living Alone 65 and over  \
# 0                                              27198
# 1                                              24477
# 2                                              28109
# 3                                              30413
# 4                                              24971
# 5                                              24645
# 6                                              26145
# 7                                              25465
# 8                                              29952
# 9                                              30557
# 10                                             33293
# 11                                             28098
# 12                                             32555
# 13                                             20418
# 14                                             24550
# 15                                             25032
# 16                                             28707
# 17                                             34067
# 18                                             31498
# 19                                             31520
# 20                                             30620
# 21                                             26545
# 22                                             27257
# 23                                             24719
# 24                                             27087
# 25                                             25487
# 26                                             22257
# 27                                             26930
# 28                                             26794
# 29                                             26475
# 30                                             28839
# 31                                             24281
# 32                                             27881
# 33                                             26628
# 34                                             23453
# 35                                             24303
# 36                                             25238
# 37                                             24886
# 38                                             22761
# 39                                             26104
# 40                                             27612
# 41                                             26998
# 42                                             30782
# 43                                             31127
# 44                                             29435
# 45                                             28069
# 46                                             28095
# 47                                             27956
# 48                                             27784
# 49                                             29069
# 50                                             32924
#
#     MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over  Male Living alone  \
# 0                                               54795                153505
# 1                                               47566                 72612
# 2                                               63704                 32734
# 3                                               63683                268365
# 4                                               51097                426811
# 5                                               59076                 62013
# 6                                               51062               1100507
# 7                                               49917                108694
# 8                                               57951                 84779
# 9                                               64011               1378550
# 10                                              66908                 35623
# 11                                              49159                192098
# 12                                              67213                355685
# 13                                              37002                138810
# 14                                              39622                 97487
# 15                                              69375                 53830
# 16                                              64711                278041
# 17                                              68729                242715
# 18                                              64387                344610
# 19                                              69819                 52768
# 20                                             133152                 51828
# 21                                              48986                307812
# 22                                              51667                 50272
# 23                                              49980                315717
# 24                                              55441                102095
# 25                                              46847                189194
# 26                                              44424                147608
# 27                                              53056                165327
# 28                                              52785                932063
# 29                                              52848                311542
# 30                                              58682                147850
# 31                                              51928                468813
# 32                                              52946                 49505
# 33                                              53485                643011
# 34                                              42422                218410
# 35                                              46155                238517
# 36                                              52826                 68516
# 37                                              48209                231009
# 38                                              42376                236519
# 39                                              68202                 33045
# 40                                              56741                317956
# 41                                              53146                629985
# 42                                              66559                341187
# 43                                              57340                 39840
# 44                                              57850                 60473
# 45                                              63402                921629
# 46                                              56783                624330
# 47                                              54029                326826
# 48                                              69966                307537
# 49                                              51299                519566
# 50                                              68633                161430
#
#     Female Living alone
# 0                145577
# 1                 86543
# 2                 32514
# 3                298983
# 4                556204
# 5                 65703
# 6               1251742
# 7                124437
# 8                 95270
# 9               1697133
# 10                28721
# 11               243275
# 12               475527
# 13               171892
# 14               119189
# 15                72181
# 16               331316
# 17               345361
# 18               401232
# 19                55960
# 20                69298
# 21               389093
# 22                46681
# 23               399545
# 24               114680
# 25               224816
# 26               179244
# 27               197253
# 28              1226856
# 29               364038
# 30               174406
# 31               626536
# 32                52250
# 33               841858
# 34               270988
# 35               304611
# 36                92604
# 37               301873
# 38               283143
# 39                43524
# 40               361097
# 41               761148
# 42               481259
# 43                54821
# 44                74063
# 45              1249943
# 46               782761
# 47               391105
# 48               428516
# 49               615296
# 50               221845

# %%
# deathrates_census.columns = [c.replace(' ', '') for c in deathrates_census.columns]
deathrates_census["Never Married Percentage"] = (deathrates_census["NeverMarried Unemployed Male"] +deathrates_census["NeverMarried Unemployed Female"]) / deathrates_census["population size"]
deathrates_census["Unemployed Below Line"] = (deathrates_census["Unemployed Male below line"] +deathrates_census["Unemployed Female below line"]) / deathrates_census["population size"]
deathrates_census["No Insurance Over 65 Below Line"] = (deathrates_census["4.00 of poverty threshold 65 years and over No health insurance coverage"] ) / deathrates_census["population size"]
deathrates_census["Living Alone Percentage"] = (deathrates_census["Male Living alone"] +deathrates_census["Female Living alone"]) / deathrates_census["population size"]
# deathrates_census.columns

# %%
# deathrates_census.head()

# %%
# Compare Deaths to median age
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'median age']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.06x +28.97

# %%
# Create Plot
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'coolwarm', s=x_axis, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('AgeAdjustedRate Compared to median age')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('median age')
plt.plot(x_axis,regress_values,"k-")
# plt.annotate(line_eq,(20,15),fontsize=15,color="red")
cbar = plt.colorbar()
cbar.set_label('median age')
plt.show()

# %%
# Compare Deaths to median household income
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'median household income']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to median household income')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Never Married Percentage')
cbar = plt.colorbar()
cbar.set_label('median household income')
plt.show()

# %%
# Compare Deaths to Never Married Percentage
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'Never Married Percentage']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Accent', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Never Married Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Never Married Percentage')
cbar = plt.colorbar()
cbar.set_label('Never Married Percentage')
plt.show()

# %%
# deathrates_census.sort_values(by='Never Married Percentage', ascending=False)

# %%
# Compare Deaths to Unemployed Male below line
plt.scatter(deathrates_census.loc[:,"AgeAdjustedRate"],deathrates_census.loc[:,'Unemployed Below Line'])
plt.title('AgeAdjustedRate Compared to Unemployed Below Line')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Unemployed Below Line')
plt.show()

# %%
# deathrates_census.sort_values(by='Unemployed Below Line', ascending=False)

# %%
# Compare Deaths to No Insurance Over 65 Below Line
plt.scatter(deathrates_census.loc[:,"AgeAdjustedRate"],deathrates_census.loc[:,'No Insurance Over 65 Below Line'])
plt.title('AgeAdjustedRate Compared to No Insurance Over 65 Below Line')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('No Insurance Over 65 Below Line')
plt.show()

# %%
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'MEDIAN HOUSEHOLD INCOME Living Alone 65 and over']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
cbar = plt.colorbar()
cbar.set_label('MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
plt.show()

# %%
# Compare Deaths to MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
plt.scatter(x_axis, deathrates_census.loc[:,'MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over'], s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over')
plt.grid(True)
plt.show()

# %%
# deathrates_census.sort_values(by='MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over', ascending=False)

# %%
# Compare Deaths to Living Alone Percentage
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'Living Alone Percentage']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Living Alone Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Living Alone Percentage')
plt.grid(True)
cbar = plt.colorbar()
cbar.set_label('Living Alone Percentage')
plt.show()

# %%
# deathrates_census.sort_values(by='Living Alone Percentage', ascending=False)
