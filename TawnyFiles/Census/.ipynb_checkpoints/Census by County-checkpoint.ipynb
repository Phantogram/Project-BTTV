# %%
import censusdata
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy import stats
import gmaps

# %%
# Specify path to read file
geo = os.path.join("Resources", "Geo out.csv")
states = os.path.join("Resources", "geocodes.xlsx")

# Read in pandas
geo_df = pd.read_csv(geo)  
states_df = pd.read_excel(states, index_col=None, convert_float=False)

# %%
# Add State and County Codes using substrings in order to join for geo locations later
geo_df["State_County"] = geo_df.County.str.split('(').str[1]
geo_df["State_County"] = geo_df.State_County.str.split(')').str[0]
geo_df["State_ID"] = geo_df.State_County.str.slice(start=0, stop=2).astype(int)
geo_df["County_ID"] = geo_df.State_County.str.slice(start=2, stop=5).astype(int)

# %%
# Filter for only County Codes
counties_df = states_df.loc[states_df['SummaryLevel'] == 50]
counties_df
# Out:
#        SummaryLevel  StateCode  CountyCode  CountySubdivisionCode  PlaceCode  \
# 2                50          1           1                      0          0
# 3                50          1           3                      0          0
# 4                50          1           5                      0          0
# 5                50          1           7                      0          0
# 6                50          1           9                      0          0
# ...             ...        ...         ...                    ...        ...
# 43905            50         72         145                      0          0
# 43906            50         72         147                      0          0
# 43907            50         72         149                      0          0
# 43908            50         72         151                      0          0
# 43909            50         72         153                      0          0
#
#        ConsolidtatedCityCode            Area Name
# 2                          0       Autauga County
# 3                          0       Baldwin County
# 4                          0       Barbour County
# 5                          0          Bibb County
# 6                          0        Blount County
# ...                      ...                  ...
# 43905                      0  Vega Baja Municipio
# 43906                      0    Vieques Municipio
# 43907                      0   Villalba Municipio
# 43908                      0    Yabucoa Municipio
# 43909                      0      Yauco Municipio
#
# [3220 rows x 7 columns]

# %%
geo_states_df = pd.merge(counties_df, geo_df, left_on=["StateCode", "CountyCode"], right_on = ["State_ID","County_ID"], how="inner")
# df_CA = geo_states_df.loc[(geo_states_df['STATE'] == 'CA')]
geo_states_df
# Out:
#       SummaryLevel  StateCode  CountyCode  CountySubdivisionCode  PlaceCode  \
# 0               50          1           1                      0          0
# 1               50          1           3                      0          0
# 2               50          1           5                      0          0
# 3               50          1           7                      0          0
# 4               50          1           9                      0          0
# ...            ...        ...         ...                    ...        ...
# 3079            50         56          37                      0          0
# 3080            50         56          39                      0          0
# 3081            50         56          41                      0          0
# 3082            50         56          43                      0          0
# 3083            50         56          45                      0          0
#
#       ConsolidtatedCityCode          Area Name STATE  AGE_ADJUSTED_RATE  \
# 0                         0     Autauga County    AL              178.3
# 1                         0     Baldwin County    AL              165.3
# 2                         0     Barbour County    AL              179.2
# 3                         0        Bibb County    AL              189.0
# 4                         0      Blount County    AL              175.3
# ...                     ...                ...   ...                ...
# 3079                      0  Sweetwater County    WY              138.0
# 3080                      0       Teton County    WY               95.0
# 3081                      0       Uinta County    WY              146.3
# 3082                      0    Washakie County    WY              126.1
# 3083                      0      Weston County    WY              149.4
#
#       COUNT  POPULATION                      County          County Name  \
# 0       556      275112      Autauga County (01001)      Autauga County
# 1      2331     1017401      Baldwin County (01003)      Baldwin County
# 2       301      130973      Barbour County (01005)      Barbour County
# 3       251      112750         Bibb County (01007)         Bibb County
# 4       653      287998       Blount County (01009)       Blount County
# ...     ...         ...                         ...                  ...
# 3079    268      222695   Sweetwater County (56037)   Sweetwater County
# 3080    107      114533        Teton County (56039)        Teton County
# 3081    147      103697        Uinta County (56041)        Uinta County
# 3082     78       41172     Washakie County (56043)     Washakie County
# 3083     75       35671       Weston County (56045)       Weston County
#
#             lat         lng  Ratings State_County  State_ID  County_ID
# 0     32.579182  -86.499655    1.783        01001         1          1
# 1     30.601074  -87.776333    1.653        01003         1          3
# 2     31.817290  -85.354965    1.792        01005         1          5
# 3     32.956280  -87.142289    1.890        01007         1          7
# 4     34.014515  -86.499655    1.753        01009         1          9
# ...         ...         ...      ...          ...       ...        ...
# 3079  41.851940 -109.188005    1.380        56037        56         37
# 3080  43.853632 -110.631449    0.950        56039        56         39
# 3081  41.210740 -110.616892    1.463        56041        56         41
# 3082  43.834783 -107.703763    1.261        56043        56         43
# 3083  43.927022 -104.472330    1.494        56045        56         45
#
# [3084 rows x 19 columns]

# %%
# Download ACS 2011-2015 5-year estimates for Oakland city, California on population size, median age, and median household income.
data = censusdata.download('acs5', 2017, censusdata.censusgeo([('county', '*')]), ['B01001_001E', 'B01002_001E', 'B19013_001E','B12006_006E','B12006_011E','B17005_006E', "B17005_011E", "C27016_041E", "B19215_005E", "B19215_008E", "B09019_027E", "B09019_030E","B19301_001E","B17001_002E","B28008_010E"])

data_table = data.rename(columns={"B01001_001E": "population size", "B01002_001E": "median age",
                                  "B19013_001E" : "median household income", "B12006_006E" : "NeverMarried Unemployed Male", 
                                  "B12006_011E" : "NeverMarried Unemployed Female", "B17005_006E" : "Unemployed Male below line", 
                                  "B17005_011E" : "Unemployed Female below line", "C27016_041E" : "4.00 of poverty threshold 65 years and over No health insurance coverage",
                                  "B19215_005E" : "MEDIAN HOUSEHOLD INCOME Living Alone 65 and over", "B19215_008E" : "MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over",
                                  "B09019_027E" : "Male Living alone", "B09019_030E" : "Female Living alone",
                                  "B19301_001E": "Per Capita Income","B17001_002E": "Poverty Count",
                                  "B28008_010E" : "Total No Computer"})

# %%
data_table.index = data_table.index.astype(str)
data_table["County_State"] = data_table.index.str.split(':').str[0]
data_table["County_Name"] = data_table.County_State.str.split(',').str[0]
data_table["State"] = data_table.County_State.str.split(',').str[1]
data_table["State_County"] = data_table.index.str.split('state:').str[1]
data_table["State_ID"] = data_table.State_County.str.split('>').str[0].astype(int)
data_table["County_ID"] = data_table.State_County.str.split('county:').str[1].astype(int)

data_table.head()
# Out:
#                                                     population size  \
# Corozal Municipio, Puerto Rico: Summary level: ...            34933
# Maunabo Municipio, Puerto Rico: Summary level: ...            11297
# Peñuelas Municipio, Puerto Rico: Summary level:...            21661
# Ponce Municipio, Puerto Rico: Summary level: 05...           148863
# San Sebastián Municipio, Puerto Rico: Summary l...            38970
#
#                                                     median age  \
# Corozal Municipio, Puerto Rico: Summary level: ...        38.1
# Maunabo Municipio, Puerto Rico: Summary level: ...        43.5
# Peñuelas Municipio, Puerto Rico: Summary level:...        36.4
# Ponce Municipio, Puerto Rico: Summary level: 05...        39.5
# San Sebastián Municipio, Puerto Rico: Summary l...        42.0
#
#                                                     median household income  \
# Corozal Municipio, Puerto Rico: Summary level: ...                    14752
# 0               50          1           1                      0          0
# 1               50          1           3                      0          0
# 2               50          1           5                      0          0
# 3               50          1           7                      0          0
# 4               50          1           9                      0          0
# ...            ...        ...         ...                    ...        ...
# 3079            50         56          37                      0          0
# 3080            50         56          39                      0          0
# 3081            50         56          41                      0          0
# 3082            50         56          43                      0          0
# 3083            50         56          45                      0          0
#
#       ConsolidtatedCityCode          Area Name STATE  AGE_ADJUSTED_RATE  \
# 0                         0     Autauga County    AL              178.3
# 1                         0     Baldwin County    AL              165.3
# 2                         0     Barbour County    AL              179.2
# 3                         0        Bibb County    AL              189.0
# 4                         0      Blount County    AL              175.3
# ...                     ...                ...   ...                ...
# 3079                      0  Sweetwater County    WY              138.0
# 3080                      0       Teton County    WY               95.0
# 3081                      0       Uinta County    WY              146.3
# 3082                      0    Washakie County    WY              126.1
# 3083                      0      Weston County    WY              149.4
#
#       COUNT  ...  Female Living alone Per Capita Income Poverty Count  \
# 0       556  ...                 2916             27824          7483
# 1      2331  ...                13677             29364         23728
# 2       301  ...                 1623             17561          6332
# 3       251  ...                  808             20911          3133
# 4       653  ...                 2782             22021          8919
# ...     ...  ...                  ...               ...           ...
# 3079    268  ...                 1843             31700          5274
# 3080    107  ...                 1356             49200          1561
# 3081    147  ...                  912             27115          3048
# 3082     78  ...                  539             27345          1039
# 3083     75  ...                  489             30955           973
#
#       Total No Computer                County_State        County_Name  \
# 0                  4846     Autauga County, Alabama     Autauga County
# 1                 16581     Baldwin County, Alabama     Baldwin County
# 2                  4693     Barbour County, Alabama     Barbour County
# 3                  4001        Bibb County, Alabama        Bibb County
# 4                  8447      Blount County, Alabama      Blount County
# ...                 ...                         ...                ...
# 3079               1927  Sweetwater County, Wyoming  Sweetwater County
# 3080                574       Teton County, Wyoming       Teton County
# 3081               1049       Uinta County, Wyoming       Uinta County
# 3082                557    Washakie County, Wyoming    Washakie County
# 3083                813      Weston County, Wyoming      Weston County
#
#          State  State_County_y  State_ID_y  County_ID_y
# 0      Alabama  01> county:001           1            1
# 1      Alabama  01> county:003           1            3
# 2      Alabama  01> county:005           1            5
# 3      Alabama  01> county:007           1            7
# 4      Alabama  01> county:009           1            9
# ...        ...             ...         ...          ...
# 3079   Wyoming  56> county:037          56           37
# 3080   Wyoming  56> county:039          56           39
# 3081   Wyoming  56> county:041          56           41
# 3082   Wyoming  56> county:043          56           43
# 3083   Wyoming  56> county:045          56           45
#
# [3084 rows x 40 columns]

# %%
# deathrates_census.columns = [c.replace(' ', '') for c in deathrates_census.columns]
deathrates_census["Never Married Percentage"] = (deathrates_census["NeverMarried Unemployed Male"] +deathrates_census["NeverMarried Unemployed Female"]) / deathrates_census["population size"]
deathrates_census["Unemployed Below Line"] = (deathrates_census["Unemployed Male below line"] +deathrates_census["Unemployed Female below line"]) / deathrates_census["population size"]
deathrates_census["No Insurance Over 65 Below Line"] = (deathrates_census["4.00 of poverty threshold 65 years and over No health insurance coverage"] ) / deathrates_census["population size"]
deathrates_census["Living Alone Percentage"] = (deathrates_census["Male Living alone"] +deathrates_census["Female Living alone"]) / deathrates_census["population size"]
deathrates_census["Income"] = (deathrates_census["median household income"] ) / 10000
deathrates_census["Poverty"] = (deathrates_census["Poverty Count"] ) / deathrates_census["population size"]
deathrates_census["No Computer"] = (deathrates_census["Total No Computer"] ) / deathrates_census["population size"]
# deathrates_census.columns

# %%
# Export file for out
compression_opts = dict(method='zip',
                        archive_name='Census out.csv')  
deathrates_census.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
summary_df = deathrates_census[["State","County_Name","AGE_ADJUSTED_RATE", "Ratings","Never Married Percentage", "Unemployed Below Line", "No Insurance Over 65 Below Line","Living Alone Percentage","median age","median household income","Poverty", "No Computer","lat","lng"]] 
summary_df
# Out:
#          State        County_Name  AGE_ADJUSTED_RATE  Ratings  \
# 0      Alabama     Autauga County              178.3    1.783
# 1      Alabama     Baldwin County              165.3    1.653
# 2      Alabama     Barbour County              179.2    1.792
# 3      Alabama        Bibb County              189.0    1.890
# 4      Alabama      Blount County              175.3    1.753
# ...        ...                ...                ...      ...
# 3079   Wyoming  Sweetwater County              138.0    1.380
# 3080   Wyoming       Teton County               95.0    0.950
# 3081   Wyoming       Uinta County              146.3    1.463
# 3082   Wyoming    Washakie County              126.1    1.261
# 3083   Wyoming      Weston County              149.4    1.494
#
#       Never Married Percentage  Unemployed Below Line  \
# 0                     0.013064               0.007050
# 1                     0.013218               0.007337
# 2                     0.026411               0.017671
# 3                     0.015988               0.006953
# 4                     0.006104               0.005098
# ...                        ...                    ...
# 3079                  0.011139               0.008849
# 3080                  0.005060               0.000000
# 3081                  0.017873               0.008238
# 3082                  0.004604               0.012601
# 3083                  0.000562               0.004918
#
#       No Insurance Over 65 Below Line  Living Alone Percentage  median age  \
# 0                            0.000000                 0.099626        37.8
# 1                            0.000000                 0.113926        42.6
# 2                            0.000000                 0.112057        39.7
# 3                            0.000000                 0.065633        39.8
# 4                            0.000000                 0.086184        40.9
# ...                               ...                      ...         ...
# 3079                         0.000292                 0.094302        34.0
# 3080                         0.000785                 0.109715        39.0
# 3081                         0.000000                 0.088448        35.1
# 3082                         0.000848                 0.111232        43.4
# 3083                         0.000000                 0.138682        42.2
#
#       median household income   Poverty  No Computer        lat         lng
# 0                       55317  0.135966     0.088051  32.579182  -86.499655
# 1                       52562  0.116680     0.081535  30.601074  -87.776333
# 2                       33368  0.241670     0.179115  31.817290  -85.354965
# 3                       43404  0.138751     0.177192  32.956280  -87.142289
# 4                       47412  0.154664     0.146479  34.014515  -86.499655
# ...                       ...       ...          ...        ...         ...
# 3079                    71083  0.118445     0.043277  41.851940 -109.188005
# 3080                    80049  0.068098     0.025040  43.853632 -110.631449
# 3081                    54672  0.146835     0.050535  41.210740 -110.616892
# 3082                    51362  0.125894     0.067491  43.834783 -107.703763
# 3083                    59605  0.136715     0.114234  43.927022 -104.472330
#
# [3084 rows x 14 columns]

# %%
# Compare Deaths to median age
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'median household income']
s = summary_df.loc[:,'Ratings']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('AgeAdjustedRate Compared to Median Household Income')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('median household income')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('median household income')
plt.show()
plt.savefig("Income.png")
# Out:
# y = -206.24x +84980.22
# -0.4471349925351067

# %%
# Compare Deaths to median household income
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'No Computer']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
# print(rvalue)

s = summary_df.loc[:,'Ratings']
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to No Computer')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('No Computer')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('No Computer')
plt.show()

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,11]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and No Computer is {round(correlation[0],2)}")
# Out:
# The correlation between rate and No Computer is 0.36

# %%
# Compare Deaths to median household income
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Poverty']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

s = summary_df.loc[:,'Ratings']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Poverty')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Poverty')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Poverty')
plt.show()
# Out:
# y = 0.0x +0.01
# 0.4031878482268183

# %%
# Compare Deaths to Living Alone Percentage
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Living Alone Percentage']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

s = deathrates_census.loc[:,'Ratings']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Living Alone Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Living Alone Percentage')
plt.grid(True)
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Living Alone Percentage')
plt.show()

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,7]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and Living Alone is {round(correlation[0],2)}")
# Out:
# y = 0.0x +0.1
# 0.06849552123917456
# The correlation between rate and Living Alone is 0.07

# %%
# Compare Deaths to unemployement
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Unemployed Below Line']
s = deathrates_census.loc[:,'Ratings']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot for Deaths to unemployement
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'coolwarm', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('AgeAdjustedRate Compared to Unemployed Below Line')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Unemployed Below Line')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Unemployed Below Line')
plt.show()
# Out:
# y = 0.0x +-0.0
# 0.3390666510892387

# %%
# Store latitude and longitude in locations
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=20,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store latitude and longitude in locations
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Living Alone Percentage"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=0,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store latitude and longitude in locations
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Poverty"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=0,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Set pearsonr correlation

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,5]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and unemployed factors is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,4]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and Never Married factors is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,6]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and no insurance is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,7]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and living alone is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,8]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and age is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,9]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and income is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,10]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and poverty is {round(correlation[0],2)}")

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,11]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and no computer is {round(correlation[0],2)}")
# Out:
# The correlation between rate and unemployed factors is 0.34
# The correlation between rate and Never Married factors is 0.2
# The correlation between rate and no insurance is -0.07
# The correlation between rate and living alone is 0.07
# The correlation between rate and age is 0.01
# The correlation between rate and income is -0.45
# The correlation between rate and poverty is 0.4
# The correlation between rate and no computer is 0.36

# %%
corr=summary_df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col8 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row0_col11 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col8 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row1_col11 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col0 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col3 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col4 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col7 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col9 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col10 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row2_col11 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col2 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col6 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col8 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col9 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col10 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row3_col11 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col0 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col1 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col2 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col3 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col5 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col8 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col9 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col10 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_54faedf4_d085_11ea_8ef6_809133825cd6row4_col11 {
#             background-color:  #6a8bef;
#             color:  #0

# %%
plt.savefig("test.png")
