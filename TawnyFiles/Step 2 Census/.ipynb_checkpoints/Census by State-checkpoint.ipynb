# %% [markdown]
# # Resrouce Library:
#
# ## Resource file name: USCS_OverviewMap
#
# ### Topic: Death Rates by State
#
# #### Source: United States Cancer Statistics: Data Visualizations
# https://gis.cdc.gov/Cancer/USCS/DataViz.html
#
# All Types of Cancer, All Ages, All Races/Ethnicities, Male and Female
# Rate per 100,000 people

# %%
import censusdata
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy import stats

# %%
# Specify path to read file
path = os.path.join("Resources", "USCS_OverviewMap.csv") #import from United States Cancer Statistics: Data Visualizations by State

# Read in pandas
df = pd.read_csv(path)

# %%
# Download ACS 2013-2017 5-year estimates on population size, median age, and median household income,etc
data = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '*')]), ['B01001_001E', 'B01002_001E', 'B19013_001E','B12006_006E','B12006_011E','B17005_006E', "B17005_011E", "C27016_041E", "B19215_005E", "B19215_008E", "B09019_027E", "B09019_030E","B992701_003E","B17001_002E"])

data_table = data.rename(columns={"B01001_001E": "population size", "B01002_001E": "median age",
                                  "B19013_001E" : "median household income", "B12006_006E" : "NeverMarried Unemployed Male", 
                                  "B12006_011E" : "NeverMarried Unemployed Female", "B17005_006E" : "Unemployed Male below line", 
                                  "B17005_011E" : "Unemployed Female below line", "C27016_041E" : "4.00 of poverty threshold 65 years and over No health insurance coverage",
                                  "B19215_005E" : "MEDIAN HOUSEHOLD INCOME Living Alone 65 and over", "B19215_008E" : "MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over",
                                  "B09019_027E" : "Male Living alone", "B09019_030E" : "Female Living alone",
                                  "B992701_003E" : "Total No health insurance", "B17001_002E": "Poverty Count"})

# %%
# convert feilds to match for state
data_table.index = data_table.index.astype(str)
data_table["Area"] = data_table.index.str.split(':').str[0]

# %%
# Merge with census  & death rate data
deathrates_census = pd.merge(df, data_table, on="Area")

# %%
# Create new coloumns to divide count by population (matching apples to apples)
deathrates_census["Never Married Percentage"] = (deathrates_census["NeverMarried Unemployed Male"] +deathrates_census["NeverMarried Unemployed Female"]) / deathrates_census["population size"]
deathrates_census["Unemployed Below Line"] = (deathrates_census["Unemployed Male below line"] +deathrates_census["Unemployed Female below line"]) / deathrates_census["population size"]
deathrates_census["No Insurance"] = (deathrates_census["Total No health insurance"] ) / deathrates_census["population size"]
deathrates_census["Living Alone Percentage"] = (deathrates_census["Male Living alone"] +deathrates_census["Female Living alone"]) / deathrates_census["population size"]
deathrates_census["Poverty"] = (deathrates_census["Poverty Count"] ) / deathrates_census["population size"]

# %%
# Export file for output
compression_opts = dict(method='zip',
                        archive_name='out.csv')  
deathrates_census.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
# Compare Deaths to median income
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'median household income']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
# print(rvalue)

r_value = print(f"The correlation between age rate and median household income age is {round(rvalue,2)}")
print(f"*Death count was adjusted for differences in age distributions")

# Create Plot
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'RdYlGn', s=x_axis, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")
plt.ylim(20000, 130000)
plt.clim(20000, 130000)
plt.xlim(100, 200)
plt.title('Deaths compared to Median Household Income by State')
plt.xlabel('Deaths 2017')
plt.ylabel('Median Household Income (Avg for 5 years)')
plt.plot(x_axis,regress_values,"k-")
plt.annotate(r_value,(20,15),fontsize=15,color="red")
cbar = plt.colorbar()
cbar.set_label('Median Household Income')
plt.show()
# Out:
# The correlation between age rate and median household income age is -0.63
# *Death count was adjusted for differences in age distributions

# %%
# Compare Deaths to median age
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'median age']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
# print(rvalue)

# Create Plot
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'RdYlGn', s=x_axis, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('Deaths Compared to Median Age by State')
plt.xlabel('Deaths 2017')
plt.ylabel('Median Age (Agvg 2014-2017)')
plt.plot(x_axis,regress_values,"k-")
# plt.annotate(line_eq,(20,15),fontsize=15,color="red")
cbar = plt.colorbar()
cbar.set_label('Median Age')
plt.show()

print(f"The correlation between age rate and median age is {round(rvalue,2)}")
# Out:
# The correlation between age rate and median age is 0.34

# %%
# Compare Deaths to Never Married Percentage
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'Never Married Percentage']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Accent', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Never Married Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Never Married Percentage')
cbar = plt.colorbar()
cbar.set_label('Never Married Percentage')
plt.show()

# %%
# Compare Deaths to Unemployed Male below line
plt.scatter(deathrates_census.loc[:,"AgeAdjustedRate"],deathrates_census.loc[:,'Unemployed Below Line'])
plt.title('AgeAdjustedRate Compared to Unemployed Below Line')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Unemployed Below Line')
plt.show()

# %%
# Compare Deaths to No Insurance
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'No Insurance']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
# print(rvalue)

r_value = print(f"The correlation between age rate and no insurance is {round(rvalue,2)}")
print(f"*Death count was adjusted for differences in age distributions")

# Create Plot
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to No Insurance')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('No Insurance')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('No Insurance')
plt.show()
# Out:
# The correlation between age rate and no insurance is 0.24
# *Death count was adjusted for differences in age distributions

# %%
# Compare Deaths to MEDIAN HOUSEHOLD INCOME Living Alone 65 and over
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'MEDIAN HOUSEHOLD INCOME Living Alone 65 and over']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
cbar = plt.colorbar()
cbar.set_label('MEDIAN HOUSEHOLD INCOME Living Alone 65 and over')
plt.show()

# %%
# Compare Deaths to MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
plt.scatter(x_axis, deathrates_census.loc[:,'MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over'], s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over')
plt.grid(True)
plt.show()

# %%
# Compare Deaths to Living Alone Percentage
x_axis = deathrates_census.loc[:,"AgeAdjustedRate"]
y_axis = deathrates_census.loc[:,'Living Alone Percentage']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=x_axis, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Living Alone Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Living Alone Percentage')
plt.grid(True)
cbar = plt.colorbar()
cbar.set_label('Living Alone Percentage')
plt.show()

# %%
# Plot out all corrilations
corr=deathrates_census.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\tawnyn\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# C:\Users\tawnyn\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col4 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col9 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col10 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col11 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col12 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col14 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col15 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col16 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col17 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col18 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col19 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col20 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col21 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row1_col22 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col1 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col3 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col4 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col6 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col7 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col8 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col9 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col10 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col11 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col12 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_648616ec_d1ca_11ea_bbd5_809133825cd6row2_col13 {
#             background-color:  #88abfd;

# %%
# create dataset for only those used in presentation
deathrates_census_summary = deathrates_census[['AgeAdjustedRate',"median age","median household income","Unemployed Below Line","No Insurance","Living Alone Percentage","Never Married Percentage","Poverty"]]

# %%
# Plot correlations for only those used in presentation
corr=deathrates_census_summary.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col1 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col3 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col4 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col5 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col6 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row0_col7 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col0 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col3 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row1_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col6 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col1 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col2 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col4 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col5 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col6 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row3_col7 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col0 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col1 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row4_col7 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col0 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col1 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col2 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col3 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col4 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col6 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row5_col7 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col0 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col1 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col2 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col3 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col4 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col5 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row6_col7 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row7_col0 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row7_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row7_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6491d994_d1ca_11ea_9cb3_809133825cd6row7_col3 {
#             background-color:  #e57058;
#             color:  #000000;
