# %% [markdown]
# # Resrouce Library
#
# ### Resource file name: Geo out
#
# ##### Topic: Death Rates by County (and State) plus counties geo locations
#
# Source: Geo Notebook

# %%
import censusdata
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy import stats
import gmaps

# %%
# Specify path to read file
geo = os.path.join("Resources", "Geo out.csv") # Imported from Geo notebook so that API doesn't have to be called each time & United States Cancer Statistics
states = os.path.join("Resources", "geocodes.xlsx") # Imported from census data to help map differnt state and county syntaxs

# Read in pandas
geo_df = pd.read_csv(geo)  
states_df = pd.read_excel(states, index_col=None, convert_float=False)

# %%
# Add State and County Codes using substrings in order to join for geo locations later
geo_df["State_County"] = geo_df.County.str.split('(').str[1]
geo_df["State_County"] = geo_df.State_County.str.split(')').str[0]
geo_df["State_ID"] = geo_df.State_County.str.slice(start=0, stop=2).astype(int)
geo_df["County_ID"] = geo_df.State_County.str.slice(start=2, stop=5).astype(int)

# %%
# Filter for only County Codes
counties_df = states_df.loc[states_df['SummaryLevel'] == 50]

# %%
# Merge geo locations with stanard state and county syntax
geo_states_df = pd.merge(counties_df, geo_df, left_on=["StateCode", "CountyCode"], right_on = ["State_ID","County_ID"], how="inner")

# %%
# Download ACS 2013-2017 5-year estimates on population size, median age, and median household income,etc
data = censusdata.download('acs5', 2017, censusdata.censusgeo([('county', '*')]), ['B01001_001E', 'B01002_001E', 'B19013_001E','B12006_006E','B12006_011E','B17005_006E', "B17005_011E", "C27016_041E", "B19215_005E", "B19215_008E", "B09019_027E", "B09019_030E","B19301_001E","B17001_002E","B28008_010E","B992701_003E"])

data_table = data.rename(columns={"B01001_001E": "population size", "B01002_001E": "median age",
                                  "B19013_001E" : "median household income", "B12006_006E" : "NeverMarried Unemployed Male", 
                                  "B12006_011E" : "NeverMarried Unemployed Female", "B17005_006E" : "Unemployed Male below line", 
                                  "B17005_011E" : "Unemployed Female below line", "C27016_041E" : "4.00 of poverty threshold 65 years and over No health insurance coverage",
                                  "B19215_005E" : "MEDIAN HOUSEHOLD INCOME Living Alone 65 and over", "B19215_008E" : "MEDIAN HOUSEHOLD INCOME Not Living Alone 65 and over",
                                  "B09019_027E" : "Male Living alone", "B09019_030E" : "Female Living alone",
                                  "B19301_001E": "Per Capita Income","B17001_002E": "Poverty Count",
                                  "B28008_010E" : "Total No Computer", "B992701_003E" : "Total No health insurance"})

# %%
# convert feilds to match for state and county merging with geo location  & death rate data
data_table.index = data_table.index.astype(str)
data_table["County_State"] = data_table.index.str.split(':').str[0]
data_table["County_Name"] = data_table.County_State.str.split(',').str[0]
data_table["State"] = data_table.County_State.str.split(',').str[1]
data_table["State_County"] = data_table.index.str.split('state:').str[1]
data_table["State_ID"] = data_table.State_County.str.split('>').str[0].astype(int)
data_table["County_ID"] = data_table.State_County.str.split('county:').str[1].astype(int)

# %%
# Merge with geo location  & death rate data
deathrates_census = pd.merge(geo_states_df, data_table, left_on=["StateCode","CountyCode"], right_on=["State_ID","County_ID"])

# %%
# Create new coloumns to divide count by population (matching apples to apples)
deathrates_census["Never Married Percentage"] = (deathrates_census["NeverMarried Unemployed Male"] +deathrates_census["NeverMarried Unemployed Female"]) / deathrates_census["population size"]
deathrates_census["Unemployed Below Line"] = (deathrates_census["Unemployed Male below line"] +deathrates_census["Unemployed Female below line"]) / deathrates_census["population size"]
deathrates_census["No Insurance"] = (deathrates_census["Total No health insurance"] ) / deathrates_census["population size"]
deathrates_census["Living Alone Percentage"] = (deathrates_census["Male Living alone"] +deathrates_census["Female Living alone"]) / deathrates_census["population size"]
deathrates_census["Income"] = (deathrates_census["median household income"] ) / 10000
deathrates_census["Poverty"] = (deathrates_census["Poverty Count"] ) / deathrates_census["population size"]
deathrates_census["No Computer"] = (deathrates_census["Total No Computer"] ) / deathrates_census["population size"]

# %%
# Export file for output to work with future dataset (i.e. weather or medically underserviced data)
compression_opts = dict(method='zip',
                        archive_name='Census out.csv')  
deathrates_census.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
# Create summary for ploting
summary_df = deathrates_census[["State","County_Name","AGE_ADJUSTED_RATE", "Ratings","Never Married Percentage", "Unemployed Below Line", "No Insurance","Living Alone Percentage","median age","median household income","Poverty", "No Computer","lat","lng", "population size"]]

# %%
# Compare Deaths to median income
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'median household income']
s = summary_df.loc[:,'AGE_ADJUSTED_RATE']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'RdYlGn', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")
plt.title('Deaths Compared to Median Household Income by County')
plt.xlabel('Deaths 2017')
plt.ylabel('Median Household Income (Avg for 5 years))')
plt.ylim(20000, 135000)
plt.xlim(50, 300)
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Median Household Income')
plt.show()
# Out:
# y = -206.24x +84980.22
# -0.4471349925351067

# %%
# Compare Deaths to no insurance
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'No Insurance']
s = deathrates_census.loc[:,'AGE_ADJUSTED_RATE']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot for Deaths to unemployement
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'RdYlGn', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('Deaths Compared to No Insurance By County')
plt.xlabel('Deaths 2017')
plt.ylabel('No Insurance (Avg for 5 years)')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('No Insurance')
plt.show()
# Out:
# y = -0.0x +0.86
# -0.05485854522937422

# %%
# Compare Deaths to age
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'median age']
s = deathrates_census.loc[:,'AGE_ADJUSTED_RATE']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot for Deaths to unemployement
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'RdYlGn', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('Deaths Compared to Median Age by County')
plt.xlabel('Deaths 2017')
plt.ylabel('Median Age (Avg for 5 years)')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Median Age')
plt.show()
# Out:
# y = 0.0x +40.9
# 0.005676919232450868

# %%
# Compare Deaths to no computure
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'No Computer']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
# print(rvalue)

s = summary_df.loc[:,'Ratings']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to No Computer')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('No Computer')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('No Computer')
plt.show()

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,11]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and No Computer is {round(rvalue,2)}")
# Out:
# The correlation between rate and No Computer is 0.36

# %%
# Compare Deaths to median household income
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Poverty']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

s = summary_df.loc[:,'Ratings']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Poverty')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Poverty')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Poverty')
plt.show()
# Out:
# y = 0.0x +0.01
# 0.4031878482268183

# %%
# Compare Deaths to Living Alone Percentage
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Living Alone Percentage']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

s = deathrates_census.loc[:,'Ratings']
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Spectral', s=s, alpha=0.75)
plt.title('AgeAdjustedRate Compared to Living Alone Percentage')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Living Alone Percentage')
plt.grid(True)
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Living Alone Percentage')
plt.show()

rate = summary_df.iloc[:,2]
factor = summary_df.iloc[:,7]
correlation = sts.pearsonr(rate,factor)
print(f"The correlation between rate and Living Alone is {round(correlation[0],2)}")
# Out:
# y = 0.0x +0.1
# 0.06849552123917456
# The correlation between rate and Living Alone is 0.07

# %%
# Compare Deaths to unemployement
x_axis = summary_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = summary_df.loc[:,'Unemployed Below Line']
s = deathrates_census.loc[:,'Ratings']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot for Deaths to unemployement
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'coolwarm', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('AgeAdjustedRate Compared to Unemployed Below Line')
plt.xlabel('AgeAdjustedRate')
plt.ylabel('Unemployed Below Line')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Unemployed Below Line')
plt.show()
# Out:
# y = 0.0x +-0.0
# 0.3390666510892387

# %%
# Plot map for cancer deaths per population
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure(center=(38.0, -95.0), zoom_level=4)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=20,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot map for living alone per population
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Living Alone Percentage"].astype(float)

# Plot Heatmap
fig = gmaps.figure(center=(38.0, -95.0), zoom_level=4)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=0,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot map for poverty per population
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["Poverty"].astype(float)

# Plot Heatmap
fig = gmaps.figure(center=(38.0, -95.0), zoom_level=4)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=0,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot map for population size per population
locations = summary_df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = summary_df["population size"].astype(float)

# Plot Heatmap
fig = gmaps.figure(center=(38.0, -95.0), zoom_level=4)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=0,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot out all corrilations
corr=summary_df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col8 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col11 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row0_col12 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col8 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col11 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row1_col12 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col0 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col3 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col4 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col7 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col9 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col10 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col11 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row2_col12 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col2 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col6 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col8 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col9 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col10 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col11 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row3_col12 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col0 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col2 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col3 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col5 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f539c9ec_d348_11ea_8f32_809133825cd6row4_col7 {
#             background-color:  #d6dce4;
#             color:

# %%
# create dataset for only those used in presentation
deathrates_census_summary = summary_df[['AGE_ADJUSTED_RATE',"median age","median household income","Unemployed Below Line","No Insurance","Living Alone Percentage","Never Married Percentage","Poverty"]]

# %%
# Plot correlations for only those used in presentation
corr=deathrates_census_summary.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_f5419292_d348_11ea_b09b_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col2 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row0_col7 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col5 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row1_col7 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col1 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col4 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col4 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col6 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row3_col7 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col0 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col1 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col2 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col3 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col5 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row4_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col1 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col3 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col6 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row5_col7 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col0 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col2 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col3 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row6_col7 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row7_col0 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row7_col1 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row7_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f5419292_d348_11ea_b09b_809133825cd6row7_col3 {
#             background-color:  #ee8468;
#             color:  #000000;
