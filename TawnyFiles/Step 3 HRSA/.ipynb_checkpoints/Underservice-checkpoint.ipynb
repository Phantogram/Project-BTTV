# %% [markdown]
# ## Resrouce Library
#
# ### Resource file name: Resource file name: Data_Explorer_Dataset_MedicalUnderservice_2014_2018
#
# #### Topic: Index of Medical Underservice Score & Providers per 100,000
#
# Source: Health Care Facilities (CMS): Medically Underserved Areas/Populations (MUA/P)
#
# orginal file name: Data_Explorer_Dataset
# https://data.hrsa.gov/tools/data-explorer
#
#
# ### Resource file name: Census out
#
# ##### Topic: Death Rates by County (and State), geolocations, and census demographics

# %%
# Dependencies
import os
import pandas as pd
import numpy as np
import gmaps
import matplotlib.pyplot as plt
from scipy import stats

# Specify path to read file
hrsa = os.path.join("Resources", "Data_Explorer_Dataset_MedicalUnderservice_2014_2018.xlsx", )
census = os.path.join("Resources", "Census out.csv")

# Read in pandas
df = pd.read_excel(hrsa, index_col=None, dtype = str) 
df.fillna('', inplace=True)

census_df = pd.read_csv(census)

# %%
# drop extra identifies
clean_census_df =  census_df.drop(columns=['SummaryLevel', 'StateCode','CountyCode','CountySubdivisionCode','PlaceCode','ConsolidtatedCityCode',
                                          'County','County Name','State_County_x','State_ID_x','County_ID_x','State_County_y','State_ID_y','County_ID_y',
                                          'County_Name','County_State','Never Married Percentage','Unemployed Below Line','No Insurance Over 65 Below Line',
                                          'Living Alone Percentage','Income','Poverty','No Computer'])

# %%
# Clean up data to select only county columns
county_df = df[df["Designation Type"] == "Medically Underserved Area"]

# Seperate county and state to merge with census data
county_df["Area"] = county_df["County"].str.split(',').str[0]
county_df["State"] = county_df["County"].str.split(', ').str[1]

# Select only the columns to be merged
county_df = county_df[['Service Area', 'MUA/P Source ID','Index of Medical Underservice Score','County', 'Area','State']]

# Convert numbers to numeric data types
county_df["Index of Medical Underservice Score"] = pd.to_numeric(county_df["Index of Medical Underservice Score"])
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Merege Census and Geo data with HRSA under serviced data
merged_county_df = pd.merge(county_df, clean_census_df, how="inner", left_on=["State","Area"], right_on=["STATE","Area Name"])

# %%
# Compare Deaths to median household income
x_axis = merged_county_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = merged_county_df.loc[:,'Index of Medical Underservice Score']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

s = merged_county_df.loc[:,'Ratings']

plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'GnBu', s=s, alpha=0.75)
plt.title('Age Adjusted Rate Compared to Medical Underservice Score')
plt.xlabel('Age Adjusted Rate')
plt.ylabel('Medical Underservice Score')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Medical Underservice Score')
plt.show()
plt.savefig("Underservice.png")
# Out:
# y = -0.03x +58.44
# -0.0745477700197967

# %%
# Compare Deaths to median age
x_axis = merged_county_df.loc[:,"AGE_ADJUSTED_RATE"]
y_axis = merged_county_df.loc[:,'median household income']
s = merged_county_df.loc[:,'Ratings']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Print Pearson's correlation coefficient (rvalue)
print(rvalue)

# Create Plot
plt.figure(figsize=(10,8))
plt.scatter(x_axis, y_axis, c=y_axis, 
            cmap = 'Set1', s=s, alpha=0.75)
plt.plot(x_axis,regress_values,"r-")

plt.title('Age Adjusted Rate Compared to Median Household Income')
plt.xlabel('Age Adjusted Rate (CDC)')
plt.ylabel('Median Household Income (Census 5 year average)')
plt.plot(x_axis,regress_values,"k-")
cbar = plt.colorbar()
cbar.set_label('Median Household Income')
plt.show()
plt.savefig("income.png")
# Out:
# y = -209.52x +85134.05
# -0.4605125310950258

# %%
corr=merged_county_df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col1 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col3 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col8 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col9 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col10 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col11 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col12 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col13 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col14 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col15 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col16 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col17 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col18 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col19 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col20 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col21 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row0_col22 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col7 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col8 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col10 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col11 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col12 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col13 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col14 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col15 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col16 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col17 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col18 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col20 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col21 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row1_col22 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col5 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col7 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col9 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col10 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col11 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col12 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_8aa03ad2_d1c7_11ea_9a18_809133825cd6row2_col13 {
#             background-color:  #b70d28;

# %%
# Select columns for site name
Site_Name_df = df[['MUA/P Source ID','Designation Type', 'Index of Medical Underservice Score', '% of Population Age 65 and Over','Rural Status']].dropna() 

# Rename columns for site name
Site_Name_df = Site_Name_df.rename(columns={'MUA/P Source ID' : 'Site Name','Designation Type' : 'Site Category', 'Index of Medical Underservice Score' : 'Site Subcategory', '% of Population Age 65 and Over' : 'Longitude','Rural Status' : 'Latitude'})

# Filter out labels (non numeric data values)
Site_Name_df = Site_Name_df[(Site_Name_df["Latitude"] != "Latitude") & (Site_Name_df["Latitude"] != "Non-Rural") & (Site_Name_df["Latitude"] != "Rural") & (Site_Name_df["Latitude"] != "Partially Rural") & (Site_Name_df["Latitude"] != "Rural") & (Site_Name_df["Latitude"] != "Unknown") & 
                            (Site_Name_df["Longitude"] != "") & (Site_Name_df["Latitude"] != "")]

# Convert to numeric
Site_Name_df["Longitude"] = pd.to_numeric(Site_Name_df["Longitude"])
Site_Name_df["Latitude"] = pd.to_numeric(Site_Name_df["Latitude"])

# %%
# Plot map for underserviced counties
locations = Site_Name_df[["Latitude", "Longitude"]]

# # Fill NaN values and convert to float
# rating = df["Count_Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations,  
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
state_df = merged_county_df[["STATE","Index of Medical Underservice Score","AGE_ADJUSTED_RATE"]]

# %%
state_df = state_df.groupby("STATE").mean()

# %%
corr=state_df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=0)
# Out:
# <style  type="text/css" >
#     #T_8b05a288_d1c7_11ea_add1_809133825cd6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8b05a288_d1c7_11ea_add1_809133825cd6row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8b05a288_d1c7_11ea_add1_809133825cd6row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8b05a288_d1c7_11ea_add1_809133825cd6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_8b05a288_d1c7_11ea_add1_809133825cd6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Index of Medical Underservice Score</th>        <th class="col_heading level0 col1" >AGE_ADJUSTED_RATE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b05a288_d1c7_11ea_add1_809133825cd6level0_row0" class="row_heading level0 row0" >Index of Medical Underservice Score</th>
#                         <td id="T_8b05a288_d1c7_11ea_add1_809133825cd6row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8b05a288_d1c7_11ea_add1_809133825cd6row0_col1" class="data row0 col1" >-0.338547</td>
#             </tr>
#             <tr>
#                         <th id="T_8b05a288_d1c7_11ea_add1_809133825cd6level0_row1" class="row_heading level0 row1" >AGE_ADJUSTED_RATE</th>
#                         <td id="T_8b05a288_d1c7_11ea_add1_809133825cd6row1_col0" class="data row1 col0" >-0.338547</td>
#                         <td id="T_8b05a288_d1c7_11ea_add1_809133825cd6row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>
