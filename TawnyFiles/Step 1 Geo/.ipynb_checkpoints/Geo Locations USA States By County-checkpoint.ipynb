# %% [markdown]
# # Resrouce Library
#
# ### Resource file name: BYAREA_COUNTY
#
# ##### Topic: Death Rates by County (and State)
#
# Source: United States Cancer Statistics (USCS) 1999–2017 zip icon[ZIP-39.5MB]
# https://www.cdc.gov/cancer/uscs/dataviz/download_data.htm

# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy import stats
import gmaps

# Google API Key
from config import gkey
from config import api_key

# %%
# Specify path to read file
path = os.path.join("Resources", "BYAREA_COUNTY.txt")

# Read dataset
dataset = pd.read_csv(path,delimiter="|")
dataset.head()

# Filter out ~ to exclude non int data
dataset = dataset[dataset.AGE_ADJUSTED_RATE != '~']

# Filter to select all races, sex, and sites
dataset_all_cancer = dataset.loc[(dataset['SITE'] == 'All Cancer Sites Combined') & (dataset['RACE'] == 'All Races') & (dataset['SEX'] == 'Male and Female')]
dataset_all_cancer.head()

# Filter to select deaths
dataset_all_cancer_deaths = dataset_all_cancer.loc[dataset_all_cancer['EVENT_TYPE'] == 'Mortality']

# Seperate out County Name from Area
dataset_all_cancer_deaths["County"] = dataset_all_cancer_deaths.AREA.str.split(':').str[1]
dataset_all_cancer_deaths["County Name"] = dataset_all_cancer_deaths.County.str.split('(').str[0]
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Add columns for lat and lng

df["lat"] = ""
df["lng"] = ""
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    county = row['County Name']
    state = row['STATE']

    # update address key value
    params['address'] = f"{county},{state}"

    # make request
    response = requests.get(base_url, params=params).json()
    
    try:
    
        df.loc[index, 'lat'] = response["results"][0]["geometry"]["location"]["lat"]
        df.loc[index, 'lng'] = response["results"][0]["geometry"]["location"]["lng"]
        
    except (KeyError, IndexError):
        df.loc[index, 'lat'] = 0
        df.loc[index, 'lng'] = 0
        print(f"Missing field/result... skipping {index}.")
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df["Ratings"] = df["AGE_ADJUSTED_RATE"].astype(float) / 100
df["Pop_Ratings"] = df["POPULATION"].astype(float) / 100000
df["Count_Ratings"] = df["COUNT"].astype(float) / 1000
# Out:
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tawnyn\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      STATE                                              AREA  \
# 984     AK    AK: Aleutians West Census Area (02016) - 1994+
# 1872    AK        AK: Anchorage Municipality (02020) - 1990+
# 2760    AK            AK: Bethel Census Area (02050) - 1990+
# 5424    AK        AK: Dillingham Census Area (02070) - 1994+
# 6312    AK  AK: Fairbanks North Star Borough (02090) - 1990+
#
#      AGE_ADJUSTED_CI_LOWER AGE_ADJUSTED_CI_UPPER AGE_ADJUSTED_RATE COUNT  \
# 984                   86.1                 303.0             174.5    23
# 1872                 144.9                 159.9             152.2  1824
# 2760                 144.5                 233.2             185.5    89
# 5424                 133.6                 282.4             198.8    36
# 6312                 136.1                 164.4             149.8   532
#
#      EVENT_TYPE  POPULATION       RACE              SEX  ... CRUDE_CI_LOWER  \
# 984   Mortality       28804  All Races  Male and Female  ...           50.6
# 1872  Mortality     1490175  All Races  Male and Female  ...          116.8
# 2760  Mortality       89833  All Races  Male and Female  ...           79.6
# 5424  Mortality       24854  All Races  Male and Female  ...          101.4
# 6312  Mortality      500222  All Races  Male and Female  ...           97.5
#
#      CRUDE_CI_UPPER CRUDE_RATE                                         County  \
# 984           119.8       79.9     Aleutians West Census Area (02016) - 1994+
# 1872          128.2      122.4         Anchorage Municipality (02020) - 1990+
# 2760          121.9       99.1             Bethel Census Area (02050) - 1990+
# 5424          200.5      144.8         Dillingham Census Area (02070) - 1994+
# 6312          115.8      106.4   Fairbanks North Star Borough (02090) - 1990+
#
#                          County Name      lat      lng Ratings Pop_Ratings  \
# 984      Aleutians West Census Area   52.3233  -174.16   1.745     0.28804
# 1872         Anchorage Municipality   61.2181   -149.9   1.522    14.90175
# 2760             Bethel Census Area   61.0934 -160.864   1.855     0.89833
# 5424         Dillingham Census Area   59.8068 -157.724   1.988     0.24854
# 6312   Fairbanks North Star Borough   64.9526 -146.474   1.498     5.00222
#
#       Count_Ratings
# 984           0.023
# 1872          1.824
# 2760          0.089
# 5424          0.036
# 6312          0.532
#
# [5 rows x 22 columns]

# %%
# Create map for cancer deaths in counties
locations = df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = df["Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=20,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create map for population in counties
locations = df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = df["Pop_Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=50,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create map for number of deaths (no adjustments) in counties
locations = df[["lat", "lng"]]

# Fill NaN values and convert to float
rating = df["Count_Ratings"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=1,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Export file to save all lat and long results from API
df_out = df[["STATE","AGE_ADJUSTED_RATE","COUNT","POPULATION","County","County Name","lat","lng","Ratings"]]

# Export file for out
compression_opts = dict(method='zip',
                        archive_name='Geo out.csv')  
df_out.to_csv('out.zip', index=False,
          compression=compression_opts)
